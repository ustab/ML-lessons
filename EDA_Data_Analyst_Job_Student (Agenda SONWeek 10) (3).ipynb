# %% [markdown]
# ___
#
# <p style='text-align: center;'><img src='https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV' class='img-fluid' alt='CLRSWY'></p>
#
# ___

# %% [markdown]
# # <h1 style="text-align: center;" class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home">EDA of DATA ANALYST JOBS</h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **What The Problem Is?**
#
# - This Exploratory Data Analysis (EDA) will focus on overall Data Analyst job title, job description, salary estimate
#
# - You'll be analyzing a dataset that contains more than 2000 job listing for data analyst positions, with features such as **Salary Estimate**, **Location**, **Company Rating**, **Job Description** and more.
#
# - You are expected to come up with different analyzes such as **finding the best jobs by salary and company rating**, **explore skills required in job descriptions**, **predict salary based on industry, location, company revenue**.
#
# **In this EDA, we will focus on:**
#    - Job Title
#    - Salary Estimate
#    - Job Description
#    - Rating
#    - Company name
#    - Industry
#    - Sector
#
# - Review what you need to make an EDA before you start analysing.

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Examining the dataset

# %% [markdown]
# **Before beginning your analysis, it's important that you familiarize yourself with the dataset.**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Import related libraries with their alias (Done for you).
# *   Read the dataset into a DataFrame named ``df``
# *   Examine the first 5 rows of the ``DataFrame`` (known as the ``'head'``).
# *   Examine the last 5 rows of the ``DataFrame`` (known as the ``'tail'``).
# *   Examine randomly chosen rows of the ``DataFrame`` (known as the ``'sample'``).
# *   Examine the ``DataFrame``'s ``'columns'``.
#
# According to your first observations, what did you detect in the dataset?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

import warnings
warnings.filterwarnings("ignore")

# %%
# CODE HERE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Cohort 11 22/DAwPy/data/DataAnalyst_week_10.csv"

# %%
df = pd.read_csv(path)

# %%
df.head(5)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\r\n\r\nProvides analytical and techni...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4  ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
#
#                                 Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\r\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\r\n3.8  New York, NY  New York, NY
# 2                         Squarespace\r\n3.4  New York, NY  New York, NY
# 3                            Celerity\r\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\r\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
df.tail(5)
# Out:
#       Unnamed: 0                                          Job Title  \
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                             Company Name        Location      Headquarters  \
# 2248                Avacend, Inc.\r\n2.5      Denver, CO    Alpharetta, GA
# 2249            Arrow Electronics\r\n2.9  Centennial, CO    Centennial, CO
# 2250                            Spiceorb      Denver, CO                -1
# 2251  Contingent Network Services\r\n3.1  Centennial, CO  West Chester, OH
# 2252                   SCL Health\r\n3.4  Broomfield, CO    Broomfield, CO
#
#                       Size  Founded       Type of ownership  \
# 2248   51 to 200 employees       -1       Company - Private
# 2249      10000+ employees     1935        Company - Public
# 2250                    -1       -1                      -1
# 2251  201 to 500 employees     1984       Company - Private
# 2252      10000+ employees     1864  Nonprofit Organization
#
#                                      Industry                  Sector  \
# 2248                   Staffing & Outsourcing       Business Services
# 2249                                Wholesale       Business Services
# 2250                                       -1                      -1
# 2251  Enterprise Software & Network Solutions  Information Technology
# 2252         Health Care Services & Hospitals             Health Care
#
#                        Revenue  \
# 2248  Unknown / Non-Applicable
# 2249        $10+ billion (USD)
# 2250                        -1
# 2251  $25 to $50 million (USD)
# 2252    $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1

# %%
df.sample()
# Out:
#      Unnamed: 0        Job Title              Salary Estimate  \
# 851         851  Data Analyst IV  $97K-$129K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 851  DescriptionTo apply to this Data Analyst IV ro...     3.5
#
#            Company Name     Location    Headquarters              Size  \
# 851  Robert Half\r\n3.5  Chicago, IL  Menlo Park, CA  10000+ employees
#
#      Founded Type of ownership                Industry             Sector  \
# 851     1948  Company - Public  Staffing & Outsourcing  Business Services
#
#                     Revenue       Competitors Easy Apply
# 851  $2 to $5 billion (USD)  Adecco, Manpower         -1

# %% [markdown]
# The column names have been standardized by making changesby means of below steps. You can continue your work after running these cells.

# %%
# !pip install skimpy
from skimpy import clean_columns

columns = ['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
       'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
       'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
       'Easy Apply']

messy_df = pd.DataFrame(data = [], columns = columns, index = [0])
clean_df = clean_columns(messy_df)
clean_df.columns.tolist()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: skimpy in /usr/local/lib/python3.7/dist-packages (0.0.5)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (7.1.2)
# Requirement already satisfied: rich<11.0.0,>=10.9.0 in /usr/local/lib/python3.7/dist-packages (from skimpy) (10.16.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (1.3.5)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in /usr/local/lib/python3.7/dist-packages (from skimpy) (2.13.3)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from skimpy) (2.12.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.3.2->skimpy) (1.15.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.4.5)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (4.1.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.9.1)
# ['unnamed_0',
#  'job_title',
#  'salary_estimate',
#  'job_description',
#  'rating',
#  'company_name',
#  'location',
#  'headquarters',
#  'size',
#  'founded',
#  'type_of_ownership',
#  'industry',
#  'sector',
#  'revenue',
#  'competitors',
#  'easy_apply']

# %%
df.columns = clean_df.columns.tolist()
df.columns
# Out:
# Index(['unnamed_0', 'job_title', 'salary_estimate', 'job_description',
#        'rating', 'company_name', 'location', 'headquarters', 'size', 'founded',
#        'type_of_ownership', 'industry', 'sector', 'revenue', 'competitors',
#        'easy_apply'],
#       dtype='object')

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Understanding The Variables
#
# **Once I knew all of the variables in the dataset, let's go on getting basic information from dataframe.**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Print shape, len, size and index of the ``DataFrame``
# *   Find how many unique values each columns have (known as the ``'nunique'``).
# *   Display all columns and their data types (known as the ``'info'``).
# *   Get some basic descriptive statistics for all numeric columns (known as the ``'describe'``).
# *   Get some basic descriptive statistics for all categoric columns (known as the ``'describe'``).
# *   Check for ``missing values``.
# *   Check for ``duplicate values``.
#
# ...

# %%
# CODE HERE
df.shape
# Out:
# (2253, 16)

# %%
df.nunique()
# Out:
# unnamed_0            2253
# job_title            1272
# salary_estimate        90
# job_description      2253
# rating                 37
# company_name         1513
# location              253
# headquarters          483
# size                    9
# founded               161
# type_of_ownership      15
# industry               89
# sector                 25
# revenue                14
# competitors           291
# easy_apply              2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   unnamed_0          2253 non-null   int64
#  1   job_title          2253 non-null   object
#  2   salary_estimate    2253 non-null   object
#  3   job_description    2253 non-null   object
#  4   rating             2253 non-null   float64
#  5   company_name       2252 non-null   object
#  6   location           2253 non-null   object
#  7   headquarters       2253 non-null   object
#  8   size               2253 non-null   object
#  9   founded            2253 non-null   int64
#  10  type_of_ownership  2253 non-null   object
#  11  industry           2253 non-null   object
#  12  sector             2253 non-null   object
#  13  revenue            2253 non-null   object
#  14  competitors        2253 non-null   object
#  15  easy_apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB

# %%
df.describe()
# Out:
#        unnamed_0       rating      founded
# count  2253.0000  2253.000000  2253.000000
# mean   1126.0000     3.160630  1398.522858
# std     650.5294     1.665228   901.929251
# min       0.0000    -1.000000    -1.000000
# 25%     563.0000     3.100000    -1.000000
# 50%    1126.0000     3.600000  1979.000000
# 75%    1689.0000     4.000000  2002.000000
# max    2252.0000     5.000000  2019.000000

# %%
df.isnull().sum()
# Out:
# unnamed_0            0
# job_title            0
# salary_estimate      0
# job_description      0
# rating               0
# company_name         1
# location             0
# headquarters         0
# size                 0
# founded              0
# type_of_ownership    0
# industry             0
# sector               0
# revenue              0
# competitors          0
# easy_apply           0
# dtype: int64

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Necessary Adjustments Before Analysis
#
# **Till now, we have got an overview to dataset to fix any issues before moving on to a more sophisticated analysis.**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Drop the ``Unnamed: 0`` column as it will not contribute to the EDA study and check the ``shape`` again.
#
# *   Replace ``(-1, -1.0, '-1')`` values with ``(np.nan)`` in the columns.
#
# *   Check for ``missing`` and ``duplicate`` values again.
#
# ...

# %%
df.columns
# Out:
# Index(['unnamed_0', 'job_title', 'salary_estimate', 'job_description',
#        'rating', 'company_name', 'location', 'headquarters', 'size', 'founded',
#        'type_of_ownership', 'industry', 'sector', 'revenue', 'competitors',
#        'easy_apply'],
#       dtype='object')

# %%
# CODE HERE
df = df.drop(columns='unnamed_0')
df
# Out:
#                                               job_title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   salary_estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    company_name        location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 2                            Squarespace\r\n3.4    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 4                                FanDuel\r\n3.9    New York, NY
# ...                                         ...             ...
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2249                   Arrow Electronics\r\n2.9  Centennial, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
# 2252                          SCL Health\r\n3.4  Broomfield, CO
#
#           headquarters                    size  founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    type_of_ownership                                 industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 sector                     revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             competitors easy_apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 15 columns]

# %%
df['competitors'] = df['competitors'].replace(to_replace='-1', value=np.nan)
df
# Out:
#                                               job_title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   salary_estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    company_name        location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 2                            Squarespace\r\n3.4    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 4                                FanDuel\r\n3.9    New York, NY
# ...                                         ...             ...
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2249                   Arrow Electronics\r\n2.9  Centennial, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
# 2252                          SCL Health\r\n3.4  Broomfield, CO
#
#           headquarters                    size  founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    type_of_ownership                                 industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 sector                     revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             competitors easy_apply
# 0                                                   NaN       True
# 1                                                   NaN         -1
# 2                                               GoDaddy         -1
# 3                                                   NaN         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                NaN         -1
# 2251                                                NaN         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 15 columns]

# %%
df['competitors'].isin(['-1', -1, -1.0, '-1.0']).value_counts()
# Out:
# False    2253
# Name: competitors, dtype: int64

# %%
df['competitors'].isin([np.nan]).value_counts()
# Out:
# True     1732
# False     521
# Name: competitors, dtype: int64

# %%
df['competitors'].unique()
# Out:
# array([nan, 'GoDaddy', 'DraftKings', 'Travelers, Chubb, Crum & Forster',
#        'Thomson Reuters, Hearst, Pearson', 'Signifyd, Forter',
#        'NewYork-Presbyterian Hospital, Northwell Health',
#        'DoubleClick, Specific Media, Collective',
#        'KPMG, Accenture, Deloitte', 'Microsoft, Apple, Facebook',
#        'Goldman Sachs, Commonwealth Bank of Australia, Deutsche Bank',
#        'Hired, Indeed, AngelList', 'Criteo, AppNexus, dataxu',
#        'News Corp, WarnerMedia, NBCUniversal',
#        'Soros Fund Management, D. E. Shaw & Co. - Investment Firm, Fortress Investment Group',
#        'Persistent Systems (India), GlobalLogic, Synechron',
#        'Google, Goldman Sachs, Thomson Reuters',
#        'MediaMath, Conversant, AppNexus',
#        'Fidelity Investments, BlackRock, Putnam Investments',
#        'Artech Information Systems, Mindlance, Tech Mahindra',
#        'Coleman Research, AlphaSights, Third Bridge',
#        'Deloitte, Huron Consulting Group, Point B',
#        'TEKsystems, Insight Global, Accenture',
#        'Jefferies, Piper Sandler, FBR', 'Adecco, Manpower',
#        'Ibotta, GutCheck', 'Accenture, CGI, Sopra Steria',
#        'Amazon, Accenture, Microsoft',
#        'Catholic Health System, NewYork-Presbyterian Hospital', 'RBC',
#        'Sky Betting & Gaming', 'IQVIA, GlobalData',
#        'Google, Microsoft, Walmart', 'Honor, HomeHero',
#        'Gartner, Forrester, IDC',
#        'Edelman, Burson-Marsteller, FleishmanHillard',
#        'Deutsche Bank, Credit Suisse, Morgan Stanley',
#        'Appen, Lionbridge',
#        'Beacon Hill Staffing Group, PageGroup, Solomon Page',
#        'Activision Blizzard, Electronic Arts',
#        'Capgemini, Accenture, Deloitte', 'G4S, Loomis, GardaWorld',
#        'Northwell Health, Stony Brook University Medical, Catholic Health Services of Long Island',
#        'Morgan Stanley, Goldman Sachs',
#        'UnitedHealth Group, Cigna, Aetna',
#        'State Street, Northern Trust, BlackRock',
#        'Mindlance, Artech Information Systems, Pyramid Consulting',
#        'EmblemHealth, UnitedHealth Group, Aetna',
#        'SAP, Salesforce, Microsoft',
#        'Teva Pharmaceuticals, Sandoz International, Perrigo',
#        'Bank Of Tokyo-Mitsubishi UFJ, Mizuho Financial Group, Citi',
#        'RELX', 'Sunrun, Vivint Solar, Trinity Solar',
#        'Fastaff, Kaiser Permanente, American Traveler',
#        'Infosys, Cognizant Technology Solutions, Tata Consultancy Services',
#        'Accenture, IBM, Capgemini',
#        'H&R Block, Liberty Tax Service, Intuit',
#        'LabCorp, Bio-Reference Labs, Thermo Fisher Scientific',
#        'Northeast Utilities', 'Arbella Insurance, Safety Insurance',
#        'Kelly',
#        'Atlantic Health System, Robert Wood Johnson University Hospital, Solaris Health System',
#        'TEKsystems, Randstad US',
#        'Collabera, Artech Information Systems, TEKsystems',
#        'J.P. Morgan, Merrill Lynch, Morgan Stanley',
#        'Citrix, VMware, Juniper Networks',
#        'General Dynamics Information Technology, ENSCO, Booz Allen Hamilton',
#        'Prescription Lifeline', 'JBS USA Holdings, Tyson Foods, Hormel',
#        'Accenture, Deloitte, PwC', 'CSC, ManTech, SAIC',
#        'First Service Networks, SMS Assist, Vixxo',
#        'Pitney Bowes, US Postal Service, Envelope Manager Software',
#        'Adobe, Akamai, Oracle', 'Acumen', 'Experis',
#        'UCLA Health, City of Hope, Keck Medicine of USC',
#        'DPR Construction, Webcor', 'Cyient',
#        'PIMCO, TCW, Oaktree Capital Management', 'Netflix, Amazon, Apple',
#        'NBCUniversal', 'Riot Games, Google, Activision Blizzard',
#        'Walt Disney Company, NBCUniversal',
#        'Kaiser Permanente, CVS Health, Walgreens',
#        'Health Net, Kaiser Permanente, Molina Healthcare',
#        'Chegg, Tutor.com, Smarthinking',
#        'Activision, Riot Games, Electronic Arts',
#        'Cedars-Sinai Medical Center, Loma Linda University Health, Harbor Hospital',
#        'HCA Healthcare, Dignity Health, Sutter Health',
#        'East West Bank, Bank of the West, First Republic Bank',
#        'Kforce, NTT DATA, IBM', 'CyberCoders, Kforce, ASGN Incorporated',
#        'OpenSymmetry, Perficient, DataClarity',
#        'Google, Microsoft, Samsung Electronics',
#        'AutoZone, eBay, Advance Auto Parts',
#        'Procter & Gamble, Nestlé, Johnson & Johnson',
#        'John Deere, Bobcat Company', 'Kelly, Manpower',
#        'Adventist Health, Providence Health & Services',
#        'J.P. Morgan, Bank of America', 'Accenture, West Monroe, Slalom',
#        'eHealth, Anthem', 'Adecco, ManpowerGroup, Allegis Corporation',
#        'Anheuser-Busch InBev, The Boston Beer Company',
#        'Cerner, Epic, Athena Health Care Systems',
#        'Redwood Logistics, Coyote Logistics, Echo Global Logistics',
#        'Robert Half, Insight Global',
#        'Continental, FCA Fiat Chrysler Automobiles',
#        'J.P. Morgan, Bank of America, U.S. Bank',
#        'Stanley Black & Decker, Milwaukee Tool',
#        'BlackRock, Nuveen, Piper Sandler', 'CIBC, RBC, TD',
#        'Cognizant Technology Solutions, Infosys, Wipro',
#        'International Paper, Graphic Packaging International, Smurfit Kappa',
#        'Capgemini, Slalom, Accenture', 'Avant, Enova, OppLoans',
#        'Blue Yonder, SAP, NCR', 'Deloitte, KPMG, PwC',
#        'Nielsen, Kantar, IRI',
#        'Wolverine Trading, Interactive Brokers, Citadel',
#        'Aon, Accenture, Marsh & McLennan Companies',
#        'Kearney, AlixPartners, Hitachi Consulting',
#        'HCA Healthcare, Vanguard Health Systems',
#        'Cisco Systems, Huawei Technologies, IBM',
#        'CVS Health, Target, Walmart',
#        'Converge, Future Electronics, Advanced MP Technology',
#        'American Tower, SBA Communications, TowerCo LLC',
#        'Carr Riggs & Ingram, Cherry Bekaert, LBMC',
#        'Transnational Foods, One Source Distributors', 'GE',
#        'Fiserv, First Data, Jack Henry & Associates',
#        'Booz Allen Hamilton, Abt Associates, Oliver Wyman',
#        'Anthem, Molina Healthcare, Humana',
#        'Kforce, PageGroup, Robert Half',
#        'DP Electric, Helix Electric, Wilson Electric', 'Adecco, Kforce',
#        'Big O Tires, Les Schwab Tire Centers, Pep Boys',
#        'Harris, Gogo, Inmarsat', 'TEKsystems, Aerotek',
#        'Advance Auto Parts, AutoZone, NAPA Auto Parts',
#        'Charles Schwab, Fidelity Investments, Edward Jones',
#        'ComforceHealth, TEKsystems, Allegis Group',
#        'GEICO, Allstate, State Farm',
#        'NEXTGEN GLOBAL RESOURCES, Wavsys, TEKsystems',
#        'MATRIX Resources, The Insource Group, TEKsystems',
#        'Walmart, Walgreens, Express Scripts',
#        'DrugDev , Bracket, Bioclinica', 'Covance, ICON',
#        'Kforce, Insight Global, Volt Consulting Group',
#        'Harvard University, Yale University, Princeton University',
#        'UnitedHealth Group, Molina Healthcare, Centene',
#        'Thermo Fisher Scientific, MilliporeSigma, Merck KGaA', 'Vaptech',
#        'The Judge Group, Addison Group, PageGroup',
#        'Chase, BB&T, SunTrust',
#        'Lockheed Martin, Northrop Grumman, Airbus',
#        'TEKsystems, CGI, SDLC Partners',
#        'PathFinder Staffing, Juno Search Partners, Robert Half',
#        'Aerotek, Kforce, Glotel', 'Pfizer, AstraZeneca, Merck',
#        'Penn Medicine, Kimmel Cancer Center Jefferson, Abington Jefferson Health',
#        'General Dynamics, Lockheed Martin',
#        'BAE Systems USA, CACI International, General Dynamics Information Technology',
#        'Infosys, Tata Consultancy Services, Wipro',
#        'PetSmart, Walmart, Costco Wholesale',
#        'Booz Allen Hamilton, Noblis, Deloitte',
#        'SAIC, Leidos, Northrop Grumman',
#        'Chenega Corporation, Chugach Alaska, ASRC Federal Holding Company',
#        'PRA Group', 'Cornerstone OnDemand, Blackboard',
#        'Sharp HealthCare, Scripps Health',
#        'PRA Group, PRA Group (Canada)', 'Thermo Fisher Scientific, Roche',
#        'Medtronic, Roche', 'Abbott, Siemens, Baxter', 'Biogen',
#        'Square, PayPal, H&R Block',
#        'Viejas Casino, Barona Casino, Pechanga Resort & Casino',
#        'Forsythe Technology, ePlus', 'CDW, PCM, SHI International',
#        'Tyler Technologies', 'ALDI, Tesco, Carrefour',
#        'Accenture, Capgemini',
#        'Ericsson-Worldwide, Huawei Technologies, Microsoft',
#        'Kforce, Mitchell Martin, Insight Global',
#        'FDIC, Office of the Comptroller of the Currency, SEC',
#        'GATX, BNSF Railway', 'Infosys, Accenture, Capgemini',
#        'Palo Alto Networks, NortonLifeLock, CrowdStrike',
#        'Yardi Systems, AppFolio',
#        'Marketing Werks, GMR Marketing, Anderson Merchandisers',
#        'Arena, HCL Technologies, PTC',
#        'Vivint Smart Home, Johnson Controls',
#        'Mortgage Connect, Amrock, Title365',
#        'SPX, Flowserve, Robbins & Myers',
#        'Edelman, Burson-Marsteller, Weber Shandwick', 'Orthofix, Stryker',
#        'Alliance Residential, Wood Partners, Trammell Crow Residential',
#        'Avant, LendingClub, Prosper.com',
#        'AIR Worldwide, EQECAT, Verisk Analytics',
#        'Audi, BMW, Mercedes-Benz International',
#        'TEKsystems, Kforce, Milestone Technologies',
#        'TEKsystems, Collabera, Artech Information Systems',
#        'STMicroelectronics, Fairchild Semiconductor, Infineon Technologies',
#        'Insight Global, Pyramid Consulting, MATRIX Resources',
#        'Salesforce, Oracle, Microsoft',
#        'Mindtree, Happiest Minds Technologies, Altran Americas',
#        'Mentor Graphics, Synopsys',
#        'TEKsystems, Artech Information Systems, PDS Tech',
#        'World Wide Technology, Astreya Partners, Taos',
#        'Amgen, Baxter, Bristol Myers Squibb',
#        'Optimal Solutions Integration, Capgemini',
#        'TEKsystems, Akraya, Intelliswift', 'Amazon, Best Buy, Apple',
#        'Skytron, STERIS, Hill-Rom', 'Chegg, StudyBlue',
#        'Sutter Health, UCSF Medical Center and UCSF Benioff Children’s Hospitals, Kaiser Permanente',
#        'InsWeb, Insure.com, Answer Financial', 'Aquent, 24 Seven Talent',
#        'Palo Alto Networks, FireEye, Juniper Networks',
#        'Lionbridge, SDL, TransPerfect',
#        'Illumina, Thermo Fisher Scientific, Oxford Nanopore Technologies',
#        'Nektar Therapeutics, Gilead Sciences, Theravance',
#        'Amazon, Apple', 'Zocdoc, Sapphire Digital', 'OneSignal', 'Epic',
#        'Interpublic Group, Omnicom, WPP', 'Bloomreach',
#        'Google, Microsoft, Apple', 'Intuit',
#        'Attain, Deloitte, Booz Allen Hamilton',
#        'Boeing, Northrop Grumman, Raytheon Technologies',
#        'American Eagle Outfitters, Ralph Lauren, J. Crew',
#        'Aerotek, WinterWyman, Hollister Staffing', 'Robert Half, Kforce',
#        'Cognizant Technology Solutions, EY, McKinsey & Company',
#        'Accenture, IBM, Infosys',
#        'Cognizant Technology Solutions, Accenture, IBM',
#        'TireHub, National Tire Warehouse, Dealer Tire',
#        'TEKMARK Global Solutions, Marlabs, IBM',
#        'Intercontinental Exchange, Euronext, Nasdaq',
#        'The Home Depot, Amazon, Walmart',
#        'Midas, Monro Auto Service and Tire Centers',
#        'C.H. Robinson, Transplace',
#        'Blizzard Entertainment, Riot Games, Electronic Arts', 'LinkedIn',
#        'Pusher, Firebase', 'Amazon, Google, Microsoft',
#        'Paxata, Datameer, Informatica', 'UserZoom, Validately',
#        'Stanford Health Care, Dignity Health, Sutter Health',
#        'Zillow, Trulia, Coldwell Banker', 'Facebook, Google, Pinterest',
#        'Silicon Valley Bank, City National Bank (Texas)',
#        'Illumina, Agilent Technologies, Roche',
#        'NortonLifeLock, McAfee, Verisign',
#        'Collabera, Mitchell Martin, The Judge Group',
#        'Bank of America, Wells Fargo, U.S. Bank', 'Accenture, Deloitte',
#        'Thermo Fisher Scientific, Abbott, Ortho Clinical Diagnostics',
#        'Redis Labs, GridGain', 'Nurx', 'Fidelity Investments, Vanguard',
#        'Kaiser Permanente, UC Davis Health, Dignity Health',
#        'Mu Sigma, ZS Associates, Fractal', 'Accenture, Deloitte, IBM',
#        'Spectrum Brands, Scotts Miracle-Gro, Newell Brands',
#        'CUNA Mutual, SWBC, Overby-Seawell',
#        'Apex Systems, Kforce, Robert Half', 'Lionbridge, Pole To Win',
#        'DHL Global Forwarding, Freight, DB Schenker, Panalpina',
#        'SDL, Keywords Studios, TransPerfect', 'Google, Amazon, Apple',
#        "Sam's Club, BJ's Wholesale Club", 'Zillow, Trulia',
#        'WeDo technologies, Intec Telecom, Amdocs',
#        "Seattle Children's, Center for Infectious Disease Research, University of Washington",
#        'Cognizant Technology Solutions, Tata Consultancy Services, Accenture',
#        'Equinix, Digital Realty, CyrusOne',
#        'Cognizant Technology Solutions, Infosys, HCL Technologies',
#        'Morningstar, Value Line, Bankrate',
#        'Checkout 51, RetailMeNot, shopkick',
#        'BNY Mellon, DTCC, Computershare', 'Lennar, Meritage Homes',
#        'Randstad, Kelly', 'AT&T, Verizon', 'Premier, Inc., Vizient',
#        'Avnet, Ingram Micro, Tech Data',
#        'Centura Health, HealthONE, Denver Health and Hospital Authority'],
#       dtype=object)

# %%
df['competitors'].isin(['-1.0']).value_counts()
# Out:
# False    2253
# Name: competitors, dtype: int64

# %%
df['easy_apply'].isin(['-1', -1, -1.0, '-1.0']).value_counts()
# Out:
# True     2173
# False      80
# Name: easy_apply, dtype: int64

# %%
df['easy_apply'] = df['easy_apply'].replace(to_replace=['-1', -1, -1.0, '-1.0'], value=np.nan)
df['easy_apply'].isin(['-1', -1, -1.0, '-1.0']).value_counts()
# Out:
# False    2253
# Name: easy_apply, dtype: int64

# %%
df.isnull().sum()
# Out:
# job_title               0
# salary_estimate         0
# job_description         0
# rating                  0
# company_name            1
# location                0
# headquarters            0
# size                    0
# founded                 0
# type_of_ownership       0
# industry                0
# sector                  0
# revenue                 0
# competitors          1732
# easy_apply           2173
# dtype: int64

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Preparing Dataset-1

# %% [markdown]
# #### To view summary information about the columns, you may use a user defined function given below.

# %%
def first_look(data, col):
    print('[',col,']')
    print('-'*30)
    print('Percent_of_Nulls   : ', '%', round(data[col].isnull().sum() / data.shape[0]*100, 2))
    print('Num_of_Nulls   : ', data[col].isnull().sum())
    print('Num_of_Uniques : ', data[col].nunique())
    print('Duplicates     : ', data.duplicated(subset = None, keep = 'first').sum())
    print(data[col].value_counts(dropna = False).sort_index())

# %%
first_look(df, 'salary_estimate')
# Out:
# [ salary_estimate ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  90
# Duplicates     :  0
# $110K-$190K (Glassdoor est.)    29
# $113K-$132K (Glassdoor est.)    29
# $24K-$48K (Glassdoor est.)      29
# $26K-$47K (Glassdoor est.)      29
# $27K-$52K (Glassdoor est.)      30
#                                 ..
# $93K-$159K (Glassdoor est.)     25
# $97K-$129K (Glassdoor est.)     30
# $98K-$114K (Glassdoor est.)     30
# $99K-$178K (Glassdoor est.)     28
# -1                               1
# Name: salary_estimate, Length: 90, dtype: int64

# %%
first_look(df, 'rating')
# Out:
# [ rating ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  37
# Duplicates     :  0
# -1.0    272
#  1.0     10
#  1.6      2
#  1.7      2
#  1.8      2
#  1.9      2
#  2.0      6
#  2.1      4
#  2.2      3
#  2.3      9
#  2.4     10
#  2.5     32
#  2.6     14
#  2.7     25
#  2.8     43
#  2.9     40
#  3.0     57
#  3.1     68
#  3.2     91
#  3.3    109
#  3.4    101
#  3.5    125
#  3.6    135
#  3.7    132
#  3.8    130
#  3.9    140
#  4.0    129
#  4.1    119
#  4.2     47
#  4.3     55
#  4.4     46
#  4.5     47
#  4.6     46
#  4.7     23
#  4.8     29
#  4.9     17
#  5.0    131
# Name: rating, dtype: int64

# %%
df['rating']=df['rating'].replace(to_replace=[-1.0,'-1.0'], value=np.nan)
df['salary_estimate']=df['salary_estimate'].replace(to_replace=[-1.0, -1, '-1.0', '-1'], value=np.nan)

# %%
first_look(df, 'size')
# Out:
# [ size ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Duplicates     :  0
# -1                         163
# 1 to 50 employees          347
# 10000+ employees           375
# 1001 to 5000 employees     348
# 201 to 500 employees       249
# 5001 to 10000 employees     97
# 501 to 1000 employees      211
# 51 to 200 employees        421
# Unknown                     42
# Name: size, dtype: int64

# %%
df['size']=df['size'].replace(to_replace=[-1, -1.0,'-1.0', '-1', 'Unknown'], value=np.nan)

# %%
first_look(df, 'size')
# Out:
# [ size ]
# ------------------------------
# Percent_of_Nulls   :  % 9.1
# Num_of_Nulls   :  205
# Num_of_Uniques :  7
# Duplicates     :  0
# 1 to 50 employees          347
# 10000+ employees           375
# 1001 to 5000 employees     348
# 201 to 500 employees       249
# 5001 to 10000 employees     97
# 501 to 1000 employees      211
# 51 to 200 employees        421
# NaN                        205
# Name: size, dtype: int64

# %%
first_look(df, 'founded')
# Out:
# [ founded ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  161
# Duplicates     :  0
# -1       660
#  1682      1
#  1698      1
#  1740      5
#  1784      9
#         ...
#  2015     28
#  2016     22
#  2017     18
#  2018     19
#  2019      4
# Name: founded, Length: 161, dtype: int64

# %%
df['founded']=df['founded'].replace(to_replace=[-1, -1.0,'-1.0', '-1'], value=np.nan)

# %%
first_look(df, 'founded')
# Out:
# [ founded ]
# ------------------------------
# Percent_of_Nulls   :  % 29.29
# Num_of_Nulls   :  660
# Num_of_Uniques :  160
# Duplicates     :  0
# 1682.0      1
# 1698.0      1
# 1740.0      5
# 1784.0      9
# 1785.0      1
#          ...
# 2016.0     22
# 2017.0     18
# 2018.0     19
# 2019.0      4
# NaN       660
# Name: founded, Length: 161, dtype: int64

# %%
first_look(df, 'type_of_ownership')
# Out:
# [ type_of_ownership ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15
# Duplicates     :  0
# -1                                 163
# College / University                34
# Company - Private                 1273
# Company - Public                   452
# Contract                            11
# Franchise                            2
# Government                          37
# Hospital                            19
# Nonprofit Organization             124
# Other Organization                  13
# Private Practice / Firm              9
# School / School District             9
# Self-employed                        2
# Subsidiary or Business Segment      89
# Unknown                             16
# Name: type_of_ownership, dtype: int64

# %%
df['type_of_ownership']=df['type_of_ownership'].replace(to_replace=[-1, -1.0,'-1.0', '-1', 'Unknown'], value=np.nan)

# %%
first_look(df, 'type_of_ownership')
# Out:
# [ type_of_ownership ]
# ------------------------------
# Percent_of_Nulls   :  % 7.94
# Num_of_Nulls   :  179
# Num_of_Uniques :  13
# Duplicates     :  0
# College / University                34
# Company - Private                 1273
# Company - Public                   452
# Contract                            11
# Franchise                            2
# Government                          37
# Hospital                            19
# Nonprofit Organization             124
# Other Organization                  13
# Private Practice / Firm              9
# School / School District             9
# Self-employed                        2
# Subsidiary or Business Segment      89
# NaN                                179
# Name: type_of_ownership, dtype: int64

# %%
first_look(df, 'industry')
# Out:
# [ industry ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  89
# Duplicates     :  0
# -1                                      353
# Accounting                               39
# Advertising & Marketing                  51
# Aerospace & Defense                      22
# Architectural & Engineering Services     13
#                                        ...
# Utilities                                 2
# Vehicle Dealers                           3
# Venture Capital & Private Equity          6
# Video Games                              20
# Wholesale                                 6
# Name: industry, Length: 89, dtype: int64

# %%
df['industry']=df['industry'].replace(to_replace=[-1, '-1'], value=np.nan)
first_look(df, 'industry')
# Out:
# [ industry ]
# ------------------------------
# Percent_of_Nulls   :  % 15.67
# Num_of_Nulls   :  353
# Num_of_Uniques :  88
# Duplicates     :  0
# Accounting                               39
# Advertising & Marketing                  51
# Aerospace & Defense                      22
# Architectural & Engineering Services     13
# Audiovisual                               1
#                                        ...
# Vehicle Dealers                           3
# Venture Capital & Private Equity          6
# Video Games                              20
# Wholesale                                 6
# NaN                                     353
# Name: industry, Length: 89, dtype: int64

# %%
df['sector']=df['sector'].replace(to_replace=[-1, -1.0,'-1.0', '-1'], value=np.nan)
first_look(df, 'sector')
# Out:
# [ sector ]
# ------------------------------
# Percent_of_Nulls   :  % 15.67
# Num_of_Nulls   :  353
# Num_of_Uniques :  24
# Duplicates     :  0
# Accounting & Legal                     43
# Aerospace & Defense                    22
# Arts, Entertainment & Recreation        7
# Biotech & Pharmaceuticals              33
# Business Services                     524
# Construction, Repair & Maintenance     16
# Consumer Services                      14
# Education                              52
# Finance                               169
# Government                             36
# Health Care                           151
# Information Technology                570
# Insurance                              51
# Manufacturing                          40
# Media                                  42
# Mining & Metals                         1
# Non-Profit                             26
# Oil, Gas, Energy & Utilities           13
# Real Estate                            12
# Restaurants, Bars & Food Services       8
# Retail                                 38
# Telecommunications                     11
# Transportation & Logistics             20
# Travel & Tourism                        1
# NaN                                   353
# Name: sector, dtype: int64

# %%
df['revenue']=df['revenue'].replace(to_replace=[-1, -1.0,'-1.0', '-1'], value=np.nan)
first_look(df, 'revenue')
# Out:
# [ revenue ]
# ------------------------------
# Percent_of_Nulls   :  % 7.23
# Num_of_Nulls   :  163
# Num_of_Uniques :  13
# Duplicates     :  0
# $1 to $2 billion (USD)               87
# $1 to $5 million (USD)              111
# $10 to $25 million (USD)            132
# $10+ billion (USD)                  189
# $100 to $500 million (USD)          218
# $2 to $5 billion (USD)              129
# $25 to $50 million (USD)            110
# $5 to $10 billion (USD)              56
# $5 to $10 million (USD)              72
# $50 to $100 million (USD)           199
# $500 million to $1 billion (USD)     79
# Less than $1 million (USD)           93
# Unknown / Non-Applicable            615
# NaN                                 163
# Name: revenue, dtype: int64

# %%
df.isnull().sum()
# Out:
# job_title               0
# salary_estimate         1
# job_description         0
# rating                272
# company_name            1
# location                0
# headquarters            0
# size                  205
# founded               660
# type_of_ownership     179
# industry              353
# sector                353
# revenue               163
# competitors          1732
# easy_apply           2173
# dtype: int64

# %%
df['headquarters']=df['headquarters'].replace(to_replace=[-1, -1.0,'-1.0', '-1'], value=np.nan)
first_look(df, 'headquarters')
# Out:
# [ headquarters ]
# ------------------------------
# Percent_of_Nulls   :  % 7.63
# Num_of_Nulls   :  172
# Num_of_Uniques :  482
# Duplicates     :  0
# Abbott Park, IL               2
# Aberdeen, United Kingdom      1
# Abingdon, United Kingdom      1
# Acton, MA                     1
# Addison, TX                   1
#                            ...
# Yakima, WA                    1
# Yorktown Heights, NY          2
# Yorktown, VA                  1
# Zurich, Switzerland           3
# NaN                         172
# Name: headquarters, Length: 483, dtype: int64

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Divide the data frame into ``numeric`` and ``categoric`` and examine columns one by one under these headings (Optional).
#
# *   In my opinion, this method provides convenience in examining large datasets. However, we will continue our analysis on a column-by-column basis for this data set.
#
# *   In this analysis, we will concentrate on the following areas:
#     - Job Title
#     - Salary Estimate
#     - Job Description
#     - Rating
#     - Company name
#     - Industry
#     - Sector
#
# ...

# %%
df.columns
# Out:
# Index(['job_title', 'salary_estimate', 'job_description', 'rating',
#        'company_name', 'location', 'headquarters', 'size', 'founded',
#        'type_of_ownership', 'industry', 'sector', 'revenue', 'competitors',
#        'easy_apply'],
#       dtype='object')

# %%
# CODE HERE
df = df.drop(columns=['location', 'size', 'founded',
       'type_of_ownership', 'revenue', 'competitors', 'headquarters',
       'easy_apply'])
df
# Out:
#                                               job_title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   salary_estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    company_name  \
# 0              Vera Institute of Justice\r\n3.2
# 1     Visiting Nurse Service of New York\r\n3.8
# 2                            Squarespace\r\n3.4
# 3                               Celerity\r\n4.1
# 4                                FanDuel\r\n3.9
# ...                                         ...
# 2248                       Avacend, Inc.\r\n2.5
# 2249                   Arrow Electronics\r\n2.9
# 2250                                   Spiceorb
# 2251         Contingent Network Services\r\n3.1
# 2252                          SCL Health\r\n3.4
#
#                                      industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 sector
# 0                           Non-Profit
# 1                          Health Care
# 2               Information Technology
# 3               Information Technology
# 4     Arts, Entertainment & Recreation
# ...                                ...
# 2248                 Business Services
# 2249                 Business Services
# 2250                               NaN
# 2251            Information Technology
# 2252                       Health Care
#
# [2253 rows x 7 columns]

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Preparing Dataset-2

# %% [markdown]
# Let's look at the each variable in detail and make required adjustment.

# %% [markdown]
# #### 'job_title' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``'job_title'`` column to get an ``overview`` of the column. You may use above given ``user defined function``.
#
# *   Count the job titles by using ``value_counts()``.
#
# *   Try to find the  ``anomalies`` in the ``job_title`` column like ``Sr. Data Analyst``, ``Sr Data Analyst``, ``Data Analyst Senior``.
#
# *   Fix any ``anomalies`` you find. You may standardize the job titles with ``str.replace``.
#
# *   Check what you fixed by counting job titles again.
#
# ...

# %%
# CODE HERE
first_look(df, 'job_title')
# Out:
# [ job_title ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  1272
# Duplicates     :  0
# #104252 Division Data and Financial Analyst                                 1
# #105009 Research Data Analyst                                               1
# (Data Analyst) BA/BSA                                                       1
# (Data Risk Analyst: Data Modeler)                                           1
# (REMOTE) Sr. Risk Analyst (IT, IS and/or Data expertise)                    1
#                                                                            ..
# a. Senior Data and Business Analyst                                         1
# eCommerce Data Analyst                                                      1
# eDiscovery Data Analyst                                                     1
# {"title":"GAO Analyst (Data Analysis)","extended":{"opening_type":null}}    1
# 【1yr OPT+Intern】Data Analyst 保实习保就业                                         1
# Name: job_title, Length: 1272, dtype: int64

# %%
df['job_title'] = df['job_title'].str.lower().str.replace('sr.', 'Senior')
df['job_title'] = df['job_title'].str.lower().str.replace('sr', 'Senior')
first_look(df, 'job_title')
# Out:
# [ job_title ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  1250
# Duplicates     :  0
# #104252 division data and financial analyst                                 1
# #105009 research data analyst                                               1
# (data analyst) ba/bsa                                                       1
# (data risk analyst: data modeler)                                           1
# (remote) senior risk analyst (it, is and/or data expertise)                 1
#                                                                            ..
# workday technical analyst- data conversions                                 1
# workforce data analyst                                                      1
# xyz data analyst                                                            1
# {"title":"gao analyst (data analysis)","extended":{"opening_type":null}}    1
# 【1yr opt+intern】data analyst 保实习保就业                                         1
# Name: job_title, Length: 1250, dtype: int64

# %%
df['job_title'] = df['job_title'].str.replace(r'[^a-z^A-Z]+', ' ')
first_look(df, 'job_title')
# Out:
# [ job_title ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  1189
# Duplicates     :  0
#  data analyst                                                             1
#  data analyst ba bsa                                                      1
#  data engineer analyst programmer career information technology devops    1
#  data risk analyst data modeler                                           1
#  division data and financial analyst                                      1
#                                                                          ..
# woocommerce data governance analyst                                       1
# workday eib data analyst                                                  1
# workday technical analyst data conversions                                1
# workforce data analyst                                                    1
# xyz data analyst                                                          1
# Name: job_title, Length: 1189, dtype: int64

# %% [markdown]
# ####  'salary_estimate' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``salary_estimate`` column to get an overview of the column.
#
# *   There is a ``missing`` value. Since the column is important for analyze, decide how to deal with this ``missing`` value.
#
# *   Type of the  ``salary_estimate`` column is ``object``. In its current form, it is not possible to perform mathematical operations that make use of the numerical values in the column values. Therefore, ``create`` columns ``'salary_maximum'``, ``'salary_minimum'`` and ``'salary_average'`` with ``float`` type using column ``values (ex $53K-$104K)`` from column ``'salary_estimate'`` (``Feature Engineering``).
#
# *   Hint: ($53K-$104K) --> for ``'salary_minimum'`` take the ``first`` number, for ``'salary_maximum'`` take the ``second`` number,  for ``'salary_average'`` get the ``sum`` of ``first`` and ``second`` numbers and ``divide by 2``.
#
# *   Check what you have done by getting samples or displaying first 5 rows.
#
# ...

# %%
# CODE HERE
first_look(df, 'salary_estimate')
# Out:
# [ salary_estimate ]
# ------------------------------
# Percent_of_Nulls   :  % 0.04
# Num_of_Nulls   :  1
# Num_of_Uniques :  89
# Duplicates     :  0
# $110K-$190K (Glassdoor est.)    29
# $113K-$132K (Glassdoor est.)    29
# $24K-$48K (Glassdoor est.)      29
# $26K-$47K (Glassdoor est.)      29
# $27K-$52K (Glassdoor est.)      30
#                                 ..
# $93K-$159K (Glassdoor est.)     25
# $97K-$129K (Glassdoor est.)     30
# $98K-$114K (Glassdoor est.)     30
# $99K-$178K (Glassdoor est.)     28
# NaN                              1
# Name: salary_estimate, Length: 90, dtype: int64

# %%
df_ = df.copy()
df_[['salary_min', 'salary_max']] = df_.salary_estimate.str.split('-', expand=True)
df_['salary_max'] = df_.salary_max.str.extract('(\d+)')
df_['salary_min']  = df_.salary_min.str.extract('(\d+)')
df_.salary_max = df_.salary_max.astype(float)
df_.salary_min = df_.salary_min.astype(float)
df_['salary_avg'] = (df_.salary_max + df_.salary_min) / 2.0
df_
# Out:
#                                               job_title  \
# 0     data analyst center on immigration and justice...
# 1                                  quality data analyst
# 2     senior data analyst insights analytics team cu...
# 3                                          data analyst
# 4                                reporting data analyst
# ...                                                 ...
# 2248                   rqs ihha q data security analyst
# 2249               senior data analyst corporate audit
# 2250  technical business analyst sql data analytics ...
# 2251                   data analyst customer experience
# 2252                        senior quality data analyst
#
#                   salary_estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    company_name  \
# 0              Vera Institute of Justice\r\n3.2
# 1     Visiting Nurse Service of New York\r\n3.8
# 2                            Squarespace\r\n3.4
# 3                               Celerity\r\n4.1
# 4                                FanDuel\r\n3.9
# ...                                         ...
# 2248                       Avacend, Inc.\r\n2.5
# 2249                   Arrow Electronics\r\n2.9
# 2250                                   Spiceorb
# 2251         Contingent Network Services\r\n3.1
# 2252                          SCL Health\r\n3.4
#
#                                      industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 sector  salary_min  salary_max  salary_avg
# 0                           Non-Profit        37.0        66.0        51.5
# 1                          Health Care        37.0        66.0        51.5
# 2               Information Technology        37.0        66.0        51.5
# 3               Information Technology        37.0        66.0        51.5
# 4     Arts, Entertainment & Recreation        37.0        66.0        51.5
# ...                                ...         ...         ...         ...
# 2248                 Business Services        78.0       104.0        91.0
# 2249                 Business Services        78.0       104.0        91.0
# 2250                               NaN        78.0       104.0        91.0
# 2251            Information Technology        78.0       104.0        91.0
# 2252                       Health Care        78.0       104.0        91.0
#
# [2253 rows x 10 columns]

# %%
first_look(df_, 'salary_max')
# Out:
# [ salary_max ]
# ------------------------------
# Percent_of_Nulls   :  % 0.04
# Num_of_Nulls   :  1
# Num_of_Uniques :  59
# Duplicates     :  0
# 38.0      29
# 42.0      30
# 44.0      29
# 45.0      28
# 47.0      29
# 48.0      29
# 52.0      58
# 53.0      30
# 54.0       8
# 56.0       4
# 59.0       4
# 61.0      28
# 63.0       4
# 66.0      90
# 67.0      62
# 68.0      59
# 69.0      30
# 70.0      31
# 72.0      19
# 74.0      62
# 75.0      28
# 76.0     116
# 77.0       3
# 78.0      80
# 81.0      32
# 82.0      57
# 85.0      30
# 86.0     100
# 87.0      76
# 88.0      68
# 89.0      18
# 90.0      18
# 91.0      28
# 92.0      29
# 93.0      79
# 94.0      58
# 96.0      22
# 99.0      26
# 100.0     27
# 101.0     27
# 102.0     28
# 103.0     58
# 104.0     68
# 110.0     30
# 112.0     18
# 113.0     30
# 114.0     30
# 116.0     48
# 120.0     28
# 122.0     28
# 123.0     28
# 124.0     31
# 127.0     44
# 129.0     30
# 132.0     58
# 151.0     28
# 159.0     25
# 178.0     28
# 190.0     29
# NaN        1
# Name: salary_max, dtype: int64

# %%
df[['salary_min', 'salary_max']] = df.salary_estimate.str.split('-', expand=True)
df['salary_max'] = df.salary_max.str.extract('(\d+)')  #extract number
df['salary_min']  = df.salary_min.str.extract('(\d+)')
df.salary_max = df.salary_max.astype(float)
df.salary_min = df.salary_min.astype(float)
df['salary_avg'] = (df.salary_max + df.salary_min) / 2.0
df.sample(10)
# Out:
#                                               job_title  \
# 116                                    erp data analyst
# 1874                                   big data analyst
# 2183                        senior data quality analyst
# 905                              data reporting analyst
# 1603                                   data analyst mpk
# 148                                        data analyst
# 335                 senior data analyst data governance
# 1754                    systems analyst data conversion
# 2033  senior business technology analyst mdm data ma...
# 276                        data analyst intex developer
#
#                  salary_estimate  \
# 116   $51K-$87K (Glassdoor est.)
# 1874  $53K-$99K (Glassdoor est.)
# 2183  $49K-$91K (Glassdoor est.)
# 905   $29K-$38K (Glassdoor est.)
# 1603  $58K-$93K (Glassdoor est.)
# 148   $59K-$85K (Glassdoor est.)
# 335   $42K-$74K (Glassdoor est.)
# 1754  $35K-$67K (Glassdoor est.)
# 2033  $46K-$86K (Glassdoor est.)
# 276   $84K-$90K (Glassdoor est.)
#
#                                         job_description  rating  \
# 116   Title\r\nERP Data Analyst\r\n\r\n14-Feb-2020\r...     3.4
# 1874  Our Client, FORTUNE® 50 home improvement compa...     NaN
# 2183  Ibotta is seeking a Senior Data Quality Analys...     3.5
# 905   See notes for additional details.\r\nBeyond Ou...     NaN
# 1603  Job Description\r\nData Analyst\r\n\r\nStrong ...     3.9
# 148   Get To Know Voice\r\n\r\nAt Voice, we are on a...     3.4
# 335   Role Senior Data Analyst - Data Governance Loc...     4.0
# 1754  Fidelity TalentSource is your destination for ...     3.9
# 2033  ZS is a professional services firm that works ...     3.8
# 276   Back to job searchData Analyst - Intex Develop...     NaN
#
#                                            company_name  \
# 116                Wildlife Conservation Society\r\n3.4
# 1874                            Data Bridge Consultants
# 2183                                      Ibotta\r\n3.5
# 905                                    Imperastaff, LLC
# 1603                            Crystal Equation\r\n3.9
# 148                                        Voice\r\n3.4
# 335                  Reliable Software Resources\r\n4.0
# 1754                       Fidelity TalentSource\r\n3.9
# 2033                               ZS Associates\r\n3.8
# 276   Delaware Investments Colorado Municipal Income...
#
#                     industry                  sector  salary_min  salary_max  \
# 116        Social Assistance              Non-Profit        51.0        87.0
# 1874                     NaN                     NaN        53.0        99.0
# 2183                Internet  Information Technology        49.0        91.0
# 905                      NaN                     NaN        29.0        38.0
# 1603             IT Services  Information Technology        58.0        93.0
# 148                      NaN                     NaN        59.0        85.0
# 335              IT Services  Information Technology        42.0        74.0
# 1754  Staffing & Outsourcing       Business Services        35.0        67.0
# 2033              Consulting       Business Services        46.0        86.0
# 276                      NaN                     NaN        84.0        90.0
#
#       salary_avg
# 116         69.0
# 1874        76.0
# 2183        70.0
# 905         33.5
# 1603        75.5
# 148         72.0
# 335         58.0
# 1754        51.0
# 2033        66.0
# 276         87.0

# %% [markdown]
# #### 'job_description' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``job_description`` column to get an overview of the column.
#
# *   Get the first ``job_description`` by ``indexing``to see what it looks like.
#
# *   Find the required skills for a Data Analyst that are ``Python``, ``SQL``, ``Excell`` and ``Tableau`` in ``'job_description'`` column and create ``'python'``, ``'SQL'``, ``excell'`` and ``tableau'`` columns according to these values. ``str.contains()`` may help you while creating new columns.
#
# * Display the ``value counts`` and ``proportions`` of each newly created column with ``value_counts``.
#
# ...

# %%
# CODE HEREa
first_look(df, 'job_description')
# Out:
# [ job_description ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2253
# Duplicates     :  0
# "Join one of the fastest Growing Company" SM Logics Inc is a leading next-generation IT products, platforms, and services company delivering guaranteed business outcomes, seamless customer experience, actionable insights and IP-led digital transformation. We bring unparalleled knowledge of domains, markets, and technology platforms, to enable our clients realize their business goals. Title Data Governance Business Analyst Location Houston, TX Duration 6 months Job Description The Data Governance Business Analyst plays a critical role in establishing policies and requirements of master data and resolves data quality issues Execute standard onboarding of technical and business metadata into the Informatica EDC and Axon environments, ensuring the population of data lineage and linkage between the technical and business metadata Excellent listening skills to understand and interpret customer and stakeholder responses Strong facilitation skills to lead requirements and user story sessions Strong interpersonal skills to help negotiate priorities and resolve conflicts among project stakeholders Strong analytical capabilities, to evaluate information gathered from multiple sources, resolve conflicts, decompose requirements into lower level details, and distinguish true business needs from proposed implementations or user requests 3-5 years of progressive business experience Must have 3+ years of hands on Informatica Data Governance (Axon), EDC, IDQ experience. Must have 3+ MDM experience. Experience in data quality tools, including data profiling, cleansing and identity resolution. ThanksRegards, Arun kumar Suvvada Sr Technical Recruiter Emailarunsmlogics.com Ph 4694055882                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# "PL/SQL and SQL, to debug, understand and identify the issues which come up day to day. b. 1. Have strong communication & Analytical skills who can articulate very well with business and cross functional teams. 2. Candidate should know how the system works from integration perspective . For example : Systems will communicate via REST API, messengers , dB links etc.. 3. Communicating to India team's with crystal clear explanation without any confusion. 4. MDM knowledge and Prior to Cisco experience would be great advantage to candidate. 5. Person should be in a position to debug the issue if we countered any issues while integrating with other systems. 6. Having Java , SQL , PL/SQL , REST API from integration perspective ,etc., who can quickly understand & debug the code."LTI values diversity and inclusion and is committed to the principles of Equal Employment Opportunity EEO/Minority/Female/Veteran/Disabled/Sexual Orientation/Gender Identity."Nearest Major Market: San JoseNearest Secondary Market: Palo AltoJob Segment: Database, SQL, Developer, Java, Cisco, Technology                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# "This role is currently work-from-home and will move to the office environment after the COVID-19 restrictions are lifted.\r\n\r\n6 month contract\r\nResponsibilities:\r\nPartner with senior business sponsors, platform supervision, and business management to enhance and support a highly visible front office Big Data project and trade blotter application\r\nAttend regular meetings and interface with various front office users and technical teams related to the project\r\nEffectively coordinate and work with Front Office users, operations, and compliance professionals.\r\nComplete detailed documentation required for various phases of the SDLC\r\nEffectively solicit and gather business requirements from relevant stakeholders\r\nAnalyze and document user requirements and determine systems needs\r\nTest new / enhanced surveillance scenarios and assist developers "de-bug .\r\nSetup JAD session with relevant stakeholders\r\nProvide Technical Documentation as needed\r\nDevelop UAT test plans and test scripts for users to perform.\r\nCoordinate UAT with required stakeholders and hold status meetings to assess progress.\r\nProvide functional support for new releases and liaise with developers as needed.\r\nWork on multiple projects and respect aggressive schedule where support may include extra hours, nights and weekends.\r\nMinimum required qualifications\r\nExperience with Front Office traders, IT support and Operation teams in a Capital Markets domain.\r\nKnowledge and experience in regulatory reporting field.\r\nStrong written communication skills in front office setting.\r\nExperience in conducting detailed business and operational analysis for problem identification, system deployment and system enhancement.\r\nExperience in compiling detailed documentation that supports the business analysis.\r\nAdvanced Project Management skills\r\nAdvanced data analysis skills in Excel, SQL and database skills (SQL Server, Oracle, Postgres)\r\nAbility to manage conflicting requests on time in a continually fast moving environment\r\nMust be a self-starter with attention to detail\r\n\r\nPreferred qualifications:\r\nStrong knowledge of capital markets products and processes\r\nStrong knowledge of capital markets regulatory environment pertaining to trades, orders , and reporting requirements\r\nAdvanced experience with SDLC process including working closely with developers, IT support, and architects\r\nExperience with programming languages including JAVA, J2EE, Python or others is a plus\r\nExperience with Big Data, Machine Learning, AI or robotics projects is a plus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# "This role is currently work-from-home and will move to the office environment after the COVID-19 restrictions are lifted.”\r\n12 Month Contract\r\n\r\nExperience:\r\n• Strong technical background to run SQL and XLS reports\r\n• Fast learner, Accurate and strong attention to detail\r\n• Excellent analytical and organization skills\r\n• Demonstrated ability to work independently and as part of a team\r\n• Ability to handle multiple project deliverables in a fast-paced environment\r\n• Excellent verbal and written communication skills\r\n• A drive for accuracy with an Agile and end-to-end continuous process improvement approach\r\n• A Plus: Experience in Banking and Finance preferred\r\n\r\nProjects to include:\r\n• Running SQL and XLS reporting and metrics on a daily, weekly, and monthly basis\r\n• Updating reporting with new data feeds and/or edits to structure of reports                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# "W2 candidates are encouraged to apply. We are unable to sponsor H1b or work with third-party candidates at this time.\r\n\r\nJob Description:\r\nThe client is in need of a seniorData Analyst that can create SSRS reports and pull data from complicated Microsoft SQL Server 2016 databases using SQL Server Management Studio and SQL Server Data Tools.\r\nAbility to write complex SQL queries and create SSRS reports.\r\nAbility to create clear and complete documentation about data, reports, and processes.\r\nPrior experience with DotNet technology (C#, VB, etc.) and Microsoft Visual Studio 2013 and above is useful.\r\nMust have strong communication skills and the ability to create clear and complete documentation about data, reports, and processes.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# · Day to Day Responsibilities:• Partners with key stakeholders in the business to identify, assess, aggregate and document risks and controls, including risks associated with new or modified products, services, distribution channels, regulations and third party operations. May present findings to various levels of leadership. Communicates results of risk assessments to governance committees, business process owners and various levels of leadership.\r\n\r\n• Contributes to the implementation of new risk policies, practices, appetites and solutions to ensure holistic understanding and management of risks according to industry best practice. Enhances strategies, tools, and methodologies to measure, monitor, and report risks.\r\n\r\n• Applies intermediate knowledge to utilize or produce analytical material for discussions with cross-functional teams to understand business objectives and influence solution strategies.\r\n\r\n• Effectively contributes in cross-functional teams to identify, assess, aggregate and mitigate current and emerging risk events.\r\n\r\n• Effectively contributes to projects that impact the organization.\r\n\r\n• Supports the formulation of stress test plans for a line of business or the enterprise including the evaluation of results, and framing of contingency plans in partnership with key business stakeholders.\r\n\r\nJob Requirements:\r\n\r\nExperience Required:\r\n\r\n• Data Profiling and analysis\r\n\r\n• Business Requirement Development\r\n\r\n• SAS, Tableau, SQL, SharePoint management of data\r\n\r\n• Data process flow analysis\r\n\r\n• Data Mapping\r\n\r\n• Business Requirements\r\n\r\n• Testing/Validation\r\n\r\n• Issue and Risk identification and remediation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# · Lead the identification and root-cause analysis of data quality issues arising through the data chain, from source system to final report.\r\n\r\n· Prioritizing data issues and collaborating with business and technology stakeholders to address and remediate issues in a timely manner based on priority and severity.\r\n\r\n· Work in conjunction with data consumers and Domain stakeholders to support data quality rules, standards, and thresholds to ensure appropriate data quality monitoring practices are in place.\r\n\r\n· Actively tracking regulatory changes and anticipating the impact these will have on the Domain’s data governance and reporting.\r\n\r\n§ Financial industry experience is required.\r\n\r\n§ A recognized under-graduate degree in business, mathematics, computer science, or a related discipline.\r\n\r\n§ A recognized post-graduate or master’s degree in business, finance, CFA, and/or FRM would be an asset.\r\n\r\n§ Knowledge of Compliance standards and best practices, with use of analysis tools for monitoring.\r\n\r\n§ Knowledge of the Bank's financial instruments, capital markets, and wholesale operational processes & controls.\r\n\r\n§ Knowledge of regulatory/liquidity reporting (e.g., 2052A, Liquidity Stress Test, Reg YY, etc.).\r\n\r\n§ Knowledge of AML/ATF legislation regulatory requirements related projects.\r\n\r\n§ Knowledge of requirements gathering, design methodology, and building test cases - detail oriented, analytical, and capable of investigating complex / technical issues.\r\n\r\n§ Able to troubleshoot data related issues and support in the authorization in maintenance and modifications.\r\n\r\n§ Good communication / presentation skills (both oral and written).\r\n\r\n§ Excellent team player by working with cross-departmental business & IT stakeholders.\r\n\r\n§ Highly motivated and committed; capable of working in a dynamic environment with aggressive timelines and multiple work streams running in parallel.\r\n\r\n§ Experience with eliciting and provided requirements and design - detail oriented, analytical, and capable of investigating complex / business issue.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Â\r\nÂ\r\nÂ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# • 3 to 5 years of experience in the areas of Embedded Analytics (SAP Business Intelligence, data warehouse and analytical reporting) and at least 3 years in utilizing visualization tools in an SAP environment\r\n\r\n• Must be able to perform as the functional and technical SAP Analytics SME\r\n\r\n• Experience working closely with client technical heads, business heads, and business analysts to understand and document business and technical requirements and constraints\r\n\r\n• Ability to work on multiple tasks/opportunities concurrently is required\r\n\r\n• Experience with advanced analytics such as predictive, AI, and machine learning is preferred\r\n\r\nCandidates should be flexible / willing to work across this delivery landscape which includes and not limited to Agile Applications Development, Support and Deployment.\r\nApplicants for employment in the US must have valid work authorization that does not now and/or will not in the future require sponsorship of a visa for employment authorization in the US by Capgemini.\r\n\r\n(Includes Data Modeler, Data Miner.) Responsible for importing, cleaning, transforming, validating and modeling data with the purpose of understanding and drawing conclusions from data (may be presented in charts, graphs, and/or tables). Also, design and develop relational databases for collecting and storing data and build and design data input and data collection mechanisms.\r\n\r\nRequired Skills and Experience:\r\n\r\nYou are responsible for data related activities such as data extraction, profiling, cleansing, de-duplication, standardization, conversion, transformation and loading, data mining, warehousing, archiving and reporting. Responsible for all activities required to ensure optimum performance and data integrity of databases in production environments, in line with the requirements. Responsible for server based databases in development and test environments including database software installation, database creation, performance and capacity design, backup and recovery design, security design.\r\n\r\n• Qualifications: 3 – 7 (2 years min relevant experience in the role) years experience, Bachelor’s Degree.\r\n\r\n• Should be proficient in Software Engineering Techniques, Software Engineering Architecture, Software Engineering Lifecycle and Data Management.\r\n\r\n• Should have progressing skills in Business Analysis, Business Knowledge, Software Engineering Leadership, Architecture Knowledge and Technical Solution Design.\r\nCapgemini is an Equal Opportunity Employer encouraging diversity in the workplace. All qualified applicants will receive consideration for employment without regard to race, national origin, gender identity/expression, age, religion, disability, sexual orientation, genetics, veteran status, marital status or any other characteristic protected by law.\r\nThis is a general description of the Duties, Responsibilities and Qualifications required for this position. Physical, mental, sensory or environmental demands may be referenced in an attempt to communicate the manner in which this position traditionally is performed. Whenever necessary to provide individuals with disabilities an equal employment opportunity, Capgemini will consider reasonable accommodations that might involve varying job requirements and/or changing the way this job is performed, provided that such accommodations do not pose an undue hardship.\r\nClick the following link for more information on your rights as an Applicant - http://www.capgemini.com/resources/equal-employment-opportunity-is-the-law\r\n\r\nAbout Capgemini\r\nA global leader in consulting, technology services and digital transformation, Capgemini is at the forefront of innovation to address the entire breadth of clients’ opportunities in the evolving world of cloud, digital and platforms. Building on its strong 50 year heritage and deep industry-specific expertise, Capgemini enables organizations to realize their business ambitions through ...
# 现在就在微信 wuyuzhou0907\r\n现在就在微信 wuyuzhou0907\r\n现在就在微信 wuyuzhou0907\r\n1. 保实习保就业 无offer退全额\r\n2. 在美留学生独家一年OPT机会(真的是一年)\r\n3. 疫情期间最佳实习解决方案, 足不出户背景提升\r\n4. 提供Offer Letter,表现优异者提供推荐信,有有转正机会\r\n2020学生求职现况:\r\n经过调研后,我们总结出在美国求职的留学生和接受留学生工作的公司比例失衡,如今的就业形势对华人留学生和新移民的标准和要求大大提高。 大部份留学生都会觉得找工作比较吃力,主要原因有这几种:语言问题、硬实力不够、文化差异、拖延、不知道从哪开始、等等\r\nEasyfind Career 实习直推领域:\r\n1. 金融\r\n2. 财会\r\n3. 咨询\r\n4. 市场营销\r\n5. 数据分析\r\n6. 科技工程等备受华人青睐的领域\r\nData Analyst Responsibilities:\r\nManaging master data, including creation, updates, and deletion.\r\nManaging users and user roles.\r\nProvide quality assurance of imported data, working with quality assurance analyst if necessary.\r\nCommissioning and decommissioning of data sets.\r\nProcessing confidential data and information according to guidelines.\r\nHelping develop reports and analysis.\r\nManaging and designing the reporting environment, including data sources, security, and metadata.\r\nSupporting the data warehouse in identifying and revising reporting requirements.\r\nSupporting initiatives for data integrity and normalization.\r\nAssessing tests and implementing new or upgraded software and assisting with strategic decisions on new systems.\r\nGenerating reports from single or multiple systems.\r\nTroubleshooting the reporting database environment and reports.\r\nEvaluating changes and updates to source production systems.\r\nTraining end users on new reports and dashboards.\r\nProviding technical expertise on data storage structures, data mining, and data cleansing.\r\nEasyfind 求职辅导平台\r\n联系电话:(714) 717-1893\r\n公司地址:630 W Duarte Rd #305, Arcadia, CA 91007\r\n营业时间: 欢迎来电咨询或者微信联系,微信号:wuyuzhou0907\r\n官方网址:www.easyfind8.com\r\nEasyfind 公司介绍:\r\n易咨范信誉生态科技有限公司汇聚、筛选、整合美国当地优质资源,组建专业的法律、医疗、教育、 金融和商业精英团队。易咨范公司将经验丰富且成功的专业人士与在美生活的学生和个人连接起来,为他们提供最可靠,最实用的服务和产品信息,以此从学习,职业规划,健康生活方式和最终成功等方面来帮助他们。公司旗下现有八大服务部门与美国留学生联盟。联盟现已成立十四个省份的留学生协会,定期举办线上线下活动,团结海内外在美留学生与个人。易咨范公司正在建立一个以信任为基础的生态系统,由此提供值得信赖的服务。同时易咨范也得到了中美两地及美属波多黎各各级政府,各类社区组织丶企业丶文教机构,和民间团体的认可与支持,为美国的本土学生和世界各国的留学生提供了广阔的发展空间和资源平台,引导同学们规划出自己的成功人生! 凭借在中美社会各界的良好口碑与优质服务,易咨范在美国为主的北美地区迅速崛起,取得了傲人的成绩,已经成为北美最专业的留学生综合资讯服务平台之一,以及中美各类机构最信赖的合作伙伴。\r\nJob Type: Internship\r\nExperience:\r\nData Analysis: 1 year (Preferred)\r\nAdditional Compensation:\r\nCommission\r\nOther forms\r\nWork Location:\r\nFully Remote\r\nThis Job Is Ideal for Someone Who Is:\r\nAdaptable/flexible -- enjoys doing work that requires frequent shifts in direction\r\nDetail-oriented -- would rather focus on the details of work than the bigger picture\r\nThis Company Describes Its Culture as:\r\nDetail-oriented -- quality and precision-focused\r\nInnovative -- innovative and risk-taking\r\nOutcome-oriented -- results-focused with strong performance culture\r\nPeople-oriented -- supportive and fairness-focused\r\nTeam-oriented -- cooperative and collaborative\r\nSchedule:\r\nMonday to Friday\r\nCompany's website:\r\nwww.easyfind8.com\r\nWork Remotely:\r\nTemporarily due to COVID-19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# Name: job_description, Length: 2253, dtype: int64

# %%
df['python'] = df.job_description.str.lower().str.contains('python')
df.sample(10)
# Out:
#                                               job_title  \
# 1179                   data analyst supporting the fbi
# 727                                        data analyst
# 393                             senior data analyst rwe
# 1657                              data strategy analyst
# 2057  lead data engineer capital markets business an...
# 1909                                       data analyst
# 429                                        data analyst
# 1149            business analyst with data domain media
# 1759                         bi data analyst specialist
# 285                tx healthcare data reporting analyst
#
#                   salary_estimate  \
# 1179  $64K-$113K (Glassdoor est.)
# 727    $60K-$66K (Glassdoor est.)
# 393   $98K-$114K (Glassdoor est.)
# 1657   $42K-$76K (Glassdoor est.)
# 2057   $47K-$74K (Glassdoor est.)
# 1909  $57K-$104K (Glassdoor est.)
# 429    $26K-$47K (Glassdoor est.)
# 1149   $37K-$44K (Glassdoor est.)
# 1759   $57K-$70K (Glassdoor est.)
# 285    $27K-$52K (Glassdoor est.)
#
#                                         job_description  rating  \
# 1179  Salary:\r\nPublished Job Title:\r\nData Analys...     2.8
# 727   Undertone stands alone among AdTech and ad net...     3.8
# 393   Sr. Data Analyst - RWE If you are a Sr. Data A...     4.2
# 1657  Data Strategy Analyst (a.k.a. Curation Optimiz...     3.2
# 2057  Job Description\r\n\r\nImportant Note: During ...     3.6
# 1909  Company Description:\r\nAngaza is a venture-ba...     4.6
# 429   Job Description\r\nTitle: Data Analyst\r\n\r\n...     4.5
# 1149  Job title: Business Analyst/Data Domain Expert...     NaN
# 1759  Job Description\r\nBI Data Analyst/Specialist\...     3.6
# 285   Position Summary\r\nA data management/analyst ...     3.5
#
#                               company_name  \
# 1179  Forfeiture Support Associates\r\n2.8
# 727                       Undertone\r\n3.8
# 393                     CyberCoders\r\n4.2
# 1657                   GroupBy Inc.\r\n3.2
# 2057                    Wells Fargo\r\n3.6
# 1909                         Angaza\r\n4.6
# 429                         Vimerse\r\n4.5
# 1149                             LiveMindz
# 1759   Global Technical Talent, LLC\r\n3.6
# 285                  SAT Healthcare\r\n3.5
#
#                                      industry                  sector  \
# 1179                   Staffing & Outsourcing       Business Services
# 727                   Advertising & Marketing       Business Services
# 393                    Staffing & Outsourcing       Business Services
# 1657  Enterprise Software & Network Solutions  Information Technology
# 2057                    Banks & Credit Unions                 Finance
# 1909  Enterprise Software & Network Solutions  Information Technology
# 429                                       NaN                     NaN
# 1149                                      NaN                     NaN
# 1759                              IT Services  Information Technology
# 285          Health Care Services & Hospitals             Health Care
#
#       salary_min  salary_max  salary_avg  python
# 1179        64.0       113.0        88.5   False
# 727         60.0        66.0        63.0   False
# 393         98.0       114.0       106.0   False
# 1657        42.0        76.0        59.0    True
# 2057        47.0        74.0        60.5    True
# 1909        57.0       104.0        80.5    True
# 429         26.0        47.0        36.5   False
# 1149        37.0        44.0        40.5    True
# 1759        57.0        70.0        63.5    True
# 285         27.0        52.0        39.5    True

# %%
df['SQL'] = df.job_description.str.upper().str.contains('SQL')
df.sample(10)
# Out:
#                           job_title               salary_estimate  \
# 609         enterprise data analyst    $35K-$45K (Glassdoor est.)
# 694   analyst financial master data  $113K-$132K (Glassdoor est.)
# 571                    data analyst   $57K-$103K (Glassdoor est.)
# 1714   data analyst program manager    $35K-$42K (Glassdoor est.)
# 1972         data scientist analyst   $82K-$116K (Glassdoor est.)
# 2041    senior product data analyst    $46K-$86K (Glassdoor est.)
# 593           business data analyst   $57K-$103K (Glassdoor est.)
# 471           research data analyst    $43K-$69K (Glassdoor est.)
# 1032  data analyst scientist intern    $43K-$94K (Glassdoor est.)
# 1330                   data analyst    $24K-$48K (Glassdoor est.)
#
#                                         job_description  rating  \
# 609   *ENTERPRISE DATA ANALYST****WHAT IS THE OPPORT...     3.6
# 694   The Job\r\n\r\nWarner Bros. Entertainment Inc....     5.0
# 571   Apply now\r\n\r\nData Analyst\r\nIrwindale, CA...     3.2
# 1714  Job â Data Analyst / Program Manager\r\n\r\nLo...     NaN
# 1972  Job Description\r\n• 3+ years of data science ...     3.9
# 2041  Since 2005, BOLD has established itself as a j...     3.6
# 593   Business Data Analyst at an established compan...     5.0
# 471   Provides IT support for research activities an...     1.0
# 1032  About Us\r\n\r\nAccess is an IIoT (Industrial ...     NaN
# 1330  Job details\r\n\r\nTitle Data Analyst 1017\r\n...     NaN
#
#                       company_name                                 industry  \
# 609      City National Bank\r\n3.6                    Banks & Credit Unions
# 694           WB Technology\r\n5.0                                      NaN
# 571   Cenergy International\r\n3.2                               Consulting
# 1714                  softsnippets                                      NaN
# 1972           Netpace, Inc\r\n3.9  Enterprise Software & Network Solutions
# 2041                   BOLD\r\n3.6                                 Internet
# 593   Connect International\r\n5.0                                      NaN
# 471                    EVMS\r\n1.0                          Vehicle Dealers
# 1032                 Minit Charger  Enterprise Software & Network Solutions
# 1330             Yeti Technologies                              IT Services
#
#                       sector  salary_min  salary_max  salary_avg  python  \
# 609                  Finance        35.0        45.0        40.0   False
# 694                      NaN       113.0       132.0       122.5   False
# 571        Business Services        57.0       103.0        80.0   False
# 1714                     NaN        35.0        42.0        38.5   False
# 1972  Information Technology        82.0       116.0        99.0   False
# 2041  Information Technology        46.0        86.0        66.0    True
# 593                      NaN        57.0       103.0        80.0   False
# 471                   Retail        43.0        69.0        56.0    True
# 1032  Information Technology        43.0        94.0        68.5   False
# 1330  Information Technology        24.0        48.0        36.0    True
#
#         SQL
# 609    True
# 694    True
# 571   False
# 1714  False
# 1972   True
# 2041   True
# 593    True
# 471    True
# 1032  False
# 1330   True

# %%
df['excel'] = df.job_description.str.lower().str.contains('excel')
df['tableau'] = df.job_description.str.lower().str.contains('tableau')
df.sample(10)
# Out:
#                                               job_title  \
# 1221                                senior data analyst
# 996                           central flow data analyst
# 233   content analyst data ba bus tech strategy inve...
# 778           senior data analyst business intelligence
# 563                       senioranalyst data operations
# 2154                               data quality analyst
# 2063                                  lead data analyst
# 1853                      data analyst metadata analyst
# 2045                                 seniordata analyst
# 1738                  system analyst data pl sql server
#
#                  salary_estimate  \
# 1221  $37K-$68K (Glassdoor est.)
# 996   $53K-$94K (Glassdoor est.)
# 233   $41K-$78K (Glassdoor est.)
# 778   $73K-$82K (Glassdoor est.)
# 563   $37K-$70K (Glassdoor est.)
# 2154  $36K-$67K (Glassdoor est.)
# 2063  $47K-$74K (Glassdoor est.)
# 1853  $53K-$99K (Glassdoor est.)
# 2045  $46K-$86K (Glassdoor est.)
# 1738  $40K-$72K (Glassdoor est.)
#
#                                         job_description  rating  \
# 1221  Who we're looking forEarth Class Mail is searc...     4.5
# 996   ACES/Central Flow is seeking Data Analysts for...     3.9
# 233   Our client, a leading global financial service...     3.0
# 778   Who we are:\r\nBraviant is a leading provider ...     4.8
# 563   Req ID: 177767\r\n\r\nThe Job\r\n\r\nWarner Br...     3.7
# 2154  Focal Systems is a fast-growing Computer Visio...     3.8
# 2063  Job Description-\r\n\r\nBrief description of y...     3.0
# 1853  Fort Mill, South Carolina\r\nSkills : Glossary...     4.1
# 2045  Job Description\r\nDuration: 6 months to start...     4.9
# 1738  Job Title: System Analyst (Data) - PL/SQl Serv...     3.9
#
#                          company_name                       industry  \
# 1221                Scaleworks\r\n4.5   Computer Hardware & Software
# 996                     Amazon\r\n3.9                       Internet
# 233   RMS Computer Corporation\r\n3.0   Computer Hardware & Software
# 778          Braviant Holdings\r\n4.8                        Lending
# 563        Turner Broadcasting\r\n3.7  TV Broadcast & Cable Networks
# 2154             Focal Systems\r\n3.8   Computer Hardware & Software
# 2063          The Accuro Group\r\n3.0         Staffing & Outsourcing
# 1853                 Collabera\r\n4.1                    IT Services
# 2045         GoAhead Solutions\r\n4.9                    IT Services
# 1738              Diverse Lynx\r\n3.9                    IT Services
#
#                       sector  salary_min  salary_max  salary_avg  python  \
# 1221  Information Technology        37.0        68.0        52.5    True
# 996   Information Technology        53.0        94.0        73.5   False
# 233   Information Technology        41.0        78.0        59.5   False
# 778                  Finance        73.0        82.0        77.5    True
# 563                    Media        37.0        70.0        53.5   False
# 2154  Information Technology        36.0        67.0        51.5   False
# 2063       Business Services        47.0        74.0        60.5   False
# 1853  Information Technology        53.0        99.0        76.0   False
# 2045  Information Technology        46.0        86.0        66.0    True
# 1738  Information Technology        40.0        72.0        56.0   False
#
#         SQL  excel  tableau
# 1221   True   True     True
# 996    True   True    False
# 233   False   True     True
# 778    True  False     True
# 563    True  False     True
# 2154  False  False    False
# 2063   True  False     True
# 1853   True  False    False
# 2045   True   True    False
# 1738   True   True    False

# %%
first_look(df, 'excel')
# Out:
# [ excel ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2
# Duplicates     :  0
# False     899
# True     1354
# Name: excel, dtype: int64

# %%
first_look(df, 'python')
# Out:
# [ python ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2
# Duplicates     :  0
# False    1616
# True      637
# Name: python, dtype: int64

# %% [markdown]
# #### 'rating' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``rating`` column to get an overview of the column.
#
# *   There are ``missing`` values. Decide what to do with them.
#
# *   If you decide to keep them to use salary and job title info on that rows, how can you fill missing values?
#
# ...

# %%
first_look(df, 'job_title')
# Out:
# [ job_title ]
# ------------------------------
# Percent_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  1189
# Duplicates     :  0
#  data analyst                                                             1
#  data analyst ba bsa                                                      1
#  data engineer analyst programmer career information technology devops    1
#  data risk analyst data modeler                                           1
#  division data and financial analyst                                      1
#                                                                          ..
# woocommerce data governance analyst                                       1
# workday eib data analyst                                                  1
# workday technical analyst data conversions                                1
# workforce data analyst                                                    1
# xyz data analyst                                                          1
# Name: job_title, Length: 1189, dtype: int64

# %%
df['senior'] = df.job_description.str.contains('senior')

# %%
# CODE HERE
first_look(df, 'rating')
# Out:
# [ rating ]
# ------------------------------
# Percent_of_Nulls   :  % 12.07
# Num_of_Nulls   :  272
# Num_of_Uniques :  36
# Duplicates     :  0
# 1.0     10
# 1.6      2
# 1.7      2
# 1.8      2
# 1.9      2
# 2.0      6
# 2.1      4
# 2.2      3
# 2.3      9
# 2.4     10
# 2.5     32
# 2.6     14
# 2.7     25
# 2.8     43
# 2.9     40
# 3.0     57
# 3.1     68
# 3.2     91
# 3.3    109
# 3.4    101
# 3.5    125
# 3.6    135
# 3.7    132
# 3.8    130
# 3.9    140
# 4.0    129
# 4.1    119
# 4.2     47
# 4.3     55
# 4.4     46
# 4.5     47
# 4.6     46
# 4.7     23
# 4.8     29
# 4.9     17
# 5.0    131
# NaN    272
# Name: rating, dtype: int64

# %%
pd.set_option('display.max_rows', None)  # or 1000

# %%
plt.figure(figsize=(12 ,6))
df.groupby(['rating','senior'])['salary_avg'].mean().plot(kind='bar')

# %%
df_['rating'] = np.where(df['rating'].isnull(), df.groupby(['rating','senior'])['salary_avg'].mean(), df['rating'])
df_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-546-763ba8c5c48e> in <module>()
# ----> 1 df_['rating'] = np.where(df['rating'].isnull(), df.groupby(['rating','senior'])['salary_avg'].mean(), df['rating'])
#       2 df_
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (2253,) (63,) (2253,)

# %% [markdown]
# #### 'company_name' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``company_name`` column to get an overview of the column.
#
# *   There are some ``numbers`` attached to the company names. Get rid of them.
#
# *   There is a ``missing value``. Check whether it can be filled via other columns or not. If not keep it.
#
# ...

# %%
# CODE HERE

# %% [markdown]
# #### 'industry' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``industry`` column to get an overview of the column.
#
# *   Everything seems ok. But there are missing values. Keep them for the sake of further analysis.
#
# ...

# %%
# CODE HERE

# %% [markdown]
# #### 'sector' column

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``industry`` column to get an overview of the column.
#
# *   Everything seems ok. But there are missing values. Keep them for the sake of further analysis.
#
# ...

# %%
# CODE HERE

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# ## Analyzing Dataset

# %% [markdown]
# We've done the general cleaning of the data so far. From now on, we will create a different datafame with the necessary columns for further analysis.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display the ``DataFrame``'s ``columns``.
# *   Create a new dataframe by copying the ``'job_title', 'rating', 'company_name', 'industry', 'sector', 'salary_maximum', 'salary_minimum', 'salary_average', 'python', 'SQL', 'excell', 'tableau'`` columns from existing dataframe and named it ``df_analyst``.
# *   Examine the first 5 rows of the DataFrame (known as the ``'head'``).
# *   Display all columns and their data types (known as the ``'info'``).
# *   Check for ``missing values``.
# *   Get some basic descriptive statistics for all numeric columns (known as the ``'describe'``). Comment on the descriptive statistics of numeric features.
# *   Get some basic descriptive statistics for all categoric columns (known as the ``'describe'``).

# %% [markdown]
# **Creating a new dataframe from the existing dataframe with related features to analyze**

# %%
# CODE HERE

# %% [markdown]
# **Frequencies Visualizations of the categorical columns**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display first ``20`` row of the ``value counts`` of ``'job_title'`` column and ``visualize`` it with ``sns.countplot``.
# *   Display first ``20`` row of the ``value counts`` of ``'company_name'`` column and ``visualize`` it with ``sns.countplot``.
# *   Display first ``20`` row of the ``value counts`` of ``'industry'`` column and ``visualize`` it with ``sns.countplot``.
# *   Display first ``20`` row of the ``value counts`` of ``'sector'`` column and ``visualize`` it with ``sns.countplot``.
# *   Display the ``value counts`` of ``'python', 'SQL', 'excell', 'tableau'`` column and ``plot`` it with ``matplotlib pie`` as ``subplot (2*2)``.

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Frequency Visualization of the boolean type columns**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Visualization of the numeric columns**

# %% [markdown]
# **INSTRUCTIONS**
#
# Work on the new dataframe ``df_analyst``.
#
# *   Display the ``descriptive statistics`` of the ``numeric columns``.
# *   Display ``minimum, maximum, mean, median and mode`` value of the numeric columns.
# *   Plot the ``distributions`` of the numeric columns with ``histogram``.
# *   Visualize the ``boxplots`` of numeric columns.
# *   Display the ``density`` of the numeric columns.

# %% [markdown]
# **Ratings of Data Analyst Jobs**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Minimum Salary of Data Analyst Jobs**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Average Salary of Data Analyst Jobs**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Maximum Salary of Data Analyst Jobs**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# OK, we have overall info about the salary of the all data analyst job advertisements.
# Next we will specifically see 'Data Analyst' job advertisement and it's salary scale

# %% [markdown]
# **Data Analyst**

# %% [markdown]
# **INSTRUCTIONS**
#
# Work on the new dataframe ``df_analyst``.
#
# *   ``Filter`` the ``job title`` for ``'Data Analyst'`` and get the ``descriptive statistics``.
# *   Display ``minimum, maximum, mean, median and mode`` value.
# *   Plot the ``distributions`` with ``histogram``.
# *   Visualize the ``boxplots``.
# *   Display the ``density``.

# %%
# CODE HERE

# %% [markdown]
# **Minimum Salary of a Data Analyst**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Average Salary of a Data Analyst**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Maximum Salary of a Data Analyst**

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# **Job Openings by Job Title**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display ``top 20 value_counts`` of ``job_title`` column.
# *   ``Visualize`` it as shown below.

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Job Openings by Industry**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display ``top 20 value_counts`` of ``industry`` column.
# *   ``Visualize`` it as shown below.

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# **Job Openings by Sector**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display ``top 20 value_counts`` of ``sector`` column.
# *   ``Visualize`` it as shown below.

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# **Required Programming Languages & Program Skills by Job Title**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display ``sum`` of ``python, excell, SQL, tableau`` column values grouped by ``job_title`` assign it to a dataframe named ``lang_skills``.
# *   Visualize ``lang_skills`` with bar plot.
# *   Visualize ``lang_skills`` with bar plot (stacked=True).

# %%
# CODE HERE

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ___
#
#
# ___

# %% [markdown]
# **Data Analyst Jobs Salary Range based on Company Name with Rating Scores**

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Display ``value_counts`` of ``company names`` with ``salary_minimum`` and ``rating`` values and assign it to a dataframe named ``company_sal_min``.
# *   Visualize ``company_sal_min`` with scatter plot in plotly.
# *   Display ``value_counts`` of ``company names`` with ``salary_average`` and ``rating`` values and assign it to a dataframe named ``company_sal_ave``.
# *   Visualize ``company_sal_ave`` with scatter plot in plotly.
# *   Display ``value_counts`` of ``company names`` with ``salary_maximum`` and ``rating`` values and assign it to a dataframe named ``company_sal_max``.
# *   Visualize ``company_sal_max`` with scatter plot in plotly.

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# CODE HERE

# %%
# CODE HERE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ___
#
# <p style='text-align: center;'><img src='https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV' class='img-fluid' alt='CLRSWY'></p>
#
# ___
